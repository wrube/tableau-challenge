# %%
import pandas as pd
from pathlib import Path

cwd = Path.cwd() / 'data' 


# Get a list of CSV files in the directory
csv_files = cwd.glob('*.csv')

data_types = {
    'start_station_id': 'object',
    'end_station_id': 'object',
    # Add more columns and their corresponding data types as needed
}


# Initialize an empty list to store DataFrames
dfs = []

# Read each CSV file into a DataFrame and append to the list
for file in csv_files:
    df = pd.read_csv(file, dtype=data_types)
    dfs.append(df)

# Concatenate the DataFrames into a single DataFrame
concatenated_df = pd.concat(dfs, ignore_index=True)

# Save the concatenated DataFrame to a new CSV file
concatenated_df.to_csv(cwd / 'citibike_April2023-March2024.csv', index=False)

# %%
concatenated_df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       E2E964A161F786AB   classic_bike  2023-08-07 19:37:47
# 1       0660F2E48E3BB87F   classic_bike  2023-08-01 13:16:22
# 2       940FC7C675232897   classic_bike  2023-08-15 17:28:23
# 3       E967660CC5CD585B   classic_bike  2023-08-01 12:44:24
# 4       D997CB0B855FE2D6   classic_bike  2023-08-08 12:31:16
# ...                  ...            ...                  ...
# 990341  71034305DEC4E3AB   classic_bike  2024-03-27 17:40:07
# 990342  52BD7EF18DBD0557   classic_bike  2024-03-15 17:25:05
# 990343  376A4B66DD546551   classic_bike  2024-03-14 22:42:14
# 990344  63F3690F5A7D58D4   classic_bike  2024-03-08 16:47:01
# 990345  6E87C99CDDA7FCE4  electric_bike  2024-03-24 11:49:27
#
#                    ended_at          start_station_name start_station_id  \
# 0       2023-08-07 19:41:14             6 St & Grand St            HB302
# 1       2023-08-01 13:26:02             6 St & Grand St            HB302
# 2       2023-08-15 17:50:35            Heights Elevator            JC059
# 3       2023-08-01 12:49:45  Hoboken Ave at Monmouth St            JC105
# 4       2023-08-08 12:40:18  Hoboken Ave at Monmouth St            JC105
# ...                     ...                         ...              ...
# 990341  2024-03-27 17:47:49               Grove St PATH            JC115
# 990342  2024-03-15 17:33:03               Grove St PATH            JC115
# 990343  2024-03-14 22:50:17               Grove St PATH            JC115
# 990344  2024-03-08 16:56:44               Grove St PATH            JC115
# 990345  2024-03-24 11:54:47               Grove St PATH            JC115
#
#                                end_station_name end_station_id  start_lat  \
# 0                            Madison St & 10 St          HB503  40.744398
# 1                               6 St & Grand St          HB302  40.744398
# 2                              Heights Elevator          JC059  40.748721
# 3       Hoboken Terminal - River St & Hudson Pl          HB102  40.735279
# 4       Hoboken Terminal - River St & Hudson Pl          HB102  40.735208
# ...                                         ...            ...        ...
# 990341                           Lafayette Park          JC078  40.719410
# 990342                           Lafayette Park          JC078  40.719410
# 990343                           Lafayette Park          JC078  40.719410
# 990344                           Lafayette Park          JC078  40.719410
# 990345                           Lafayette Park          JC078  40.719148
#
#         start_lng    end_lat    end_lng member_casual
# 0      -74.034501  40.749943 -74.035865        member
# 1      -74.034501  40.744398 -74.034501        member
# 2      -74.040480  40.748716 -74.040443        member
# 3      -74.046830  40.736068 -74.029127        member
# 4      -74.046964  40.736068 -74.029127        member
# ...           ...        ...        ...           ...
# 990341 -74.043090  40.713464 -74.062859        member
# 990342 -74.043090  40.713464 -74.062859        member
# 990343 -74.043090  40.713464 -74.062859        member
# 990344 -74.043090  40.713464 -74.062859        member
# 990345 -74.043232  40.713464 -74.062859        member
#
# [990346 rows x 13 columns]
